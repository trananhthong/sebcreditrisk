# %%
import sebcreditrisk
import numpy as np
import pandas as pd
import scipy.stats as ss

# %%
pd.read_excel('../../../Mig_Mat_Nordic_SME_LC_RE.xlsx')
# Out:
#                          Migration_Categorie       ReportName  \
# 0      Rolling yearly with semi-annual steps  Q2/2007-Q2/2008
# 1      Rolling yearly with semi-annual steps  Q2/2007-Q2/2008
# 2      Rolling yearly with semi-annual steps  Q2/2007-Q2/2008
# 3      Rolling yearly with semi-annual steps  Q2/2007-Q2/2008
# 4      Rolling yearly with semi-annual steps  Q2/2007-Q2/2008
# ...                                      ...              ...
# 58996  Rolling yearly with semi-annual steps  Q4/2014-Q4/2015
# 58997  Rolling yearly with semi-annual steps  Q4/2014-Q4/2015
# 58998  Rolling yearly with semi-annual steps  Q4/2014-Q4/2015
# 58999  Rolling yearly with semi-annual steps  Q4/2014-Q4/2015
# 59000  Rolling yearly with semi-annual steps  Q4/2014-Q4/2015
#
#        Facility_Asset_Class DA_COUNTRY_OF_RESIDENCE  Primary_Industry  \
# 0                         1                      DK               250
# 1                         1                      DK               250
# ...
